# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import re
import time

# %%
def print_progressbar(total, i):
    """
    total : total iteration number.
    i : iteration count, starting from 0.
    """
    import math
    step = 25 / total

    # Print the progress bar
    print('\r' + f'Progress: '
        f"[{'=' * int((i+1) * step) + ' ' * (25 - int((i+1) * step))}]"
        f"({math.floor((i+1) * 100 / (total))} %) ({i+1}/{total})",
        end='')
    if (i+1) == total: print("")

# %%
# null dataframe build
df = pd.DataFrame(columns=['name', 'author', 'Journal' ,'year', 'info'])

# target journal

url = "https://scholar.google.co.kr/scholar?hl=ko&as_sdt=0%2C5&q=crohn%27s+disease+early+surgery+prediction&btnG=&oq=crohn"
url = url.replace(f'hl=ko&',f'start=0&')

# number of article
num_article = 10

for i in range(0,100):
    html = url
    req_info = requests.get(html)
    
    ## page information read using BeautifulSoup
    soup = BeautifulSoup(req_info.content,"html.parser")
    time.sleep(5)
    
    article = soup.find("div").find("div", {'id': 'gs_res_ccl'}).find("div", {'id': 'gs_res_ccl_mid'}).find_all("div", {'class': 'gs_r gs_or gs_scl'})[0]
    
    ## article name
    
    name = article.find("div",{'class':'gs_ri'}).find("h3").text
    
    ## author, Journal, time
    author_time = article.find("div",{'class':'gs_ri'}).find("div",{'class':'gs_a'}).text
    author = author_time.split("\xa0-")[0].split(",")[0:2]
    
    if '\xa0' in author_time:
        Journal = author_time.split("\xa0-")[-1].split(",")[0]
    else:
        Journal = "None"
    
    year = re.findall("\d+",author_time)[0]
    
    ## article info
    if article.find_all("div",{'class':"gs_fl"})[0].text[0]=='[' :
        info = article.find_all("div",{'class':"gs_fl"})[1].text.strip()
    else:
        info = article.find("div",{'class':"gs_fl"}).text.strip()
    
    

    df = df.append({
    'name' : name,
    'author' : author,
    'Journal' : Journal,
    'year' : year,
    'info' : info,
    }, ignore_index=True)
    
    url = url.replace(f'{i}&',f'{i+1}&')
    print_progressbar(100, i)
    time.sleep(5)


# dataframe save

df_filename = "crawling_result"

df.to_csv(df_filename, encoding='utf-8-sig', index=False)
# Out:
# Progress: [====                     ](16 %) (16/100)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-240-41ef2a83356c> in <module>
#      34     time.sleep(5)
#      35
# ---> 36     article = soup.find("div").find("div", {'id': 'gs_res_ccl'}).find("div", {'id': 'gs_res_ccl_mid'}).find_all("div", {'class': 'gs_r gs_or gs_scl'})[0]
#      37
#      38     ## article name
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
df
# Out:
#                                                  name  \
# 0   Upper gastrointestinal tract phenotype of Croh...
# 1   Utility of serological markers in predicting t...
# 2   Biologics delay progression of Crohn's disease...
# 3   Predicting complicated Crohn's disease and sur...
# 4   Risk factors for early postoperative recurrenc...
# 5   European Crohn's and Colitis Organisation topi...
# 6   The value of myenteric plexitis to predict ear...
# 7   Anti-Saccharomyces cerevisiae antibody (ASCA) ...
# 8   Multidimensional prognostic risk assessment id...
# 9   Genetic risk profiling and prediction of disea...
# 10  Development of clinical prediction models for ...
# 11               Predictors of severe Crohn's disease
# 12  Genotype-phenotype analysis in childhood-onset...
# 13  Prediction of disease complication occurrence ...
# 14  Serum anti-glycan antibodies predict complicat...
# 15  Histologic features predicting postoperative C...
#
#                                author                       Journal  year  \
# 0               [DKL Chow,  JJY Sung]              … bowel diseases  2009
# 1                   [DK Amre,  SE Lu]                          None  2006
# 2               [B Kerur,  JT Machan]                    Clinical …  2018
# 3           [JD Ryan,  MS Silverberg]                  Alimentary …  2013
# 4          [E Lautenbach,  JA Berlin]              Gastroenterology  1998
# 5              [F Rieder,  G Latella]          Journal of Crohn's …  2016
# 6         [M Ferrante,  G De Hertogh]              Gastroenterology  2006
# 7            [DG Forcione,  MJ Rosen]                           Gut  2004
# 8        [MC Dubinsky,  S Kugathasan]              … bowel diseases  2013
# 9        [L Henckaerts,  K Van Steen]                    Clinical …  2009
# 10              [L Guizzetti,  G Zou]          Journal of Crohn's …  2018
# 11              [C Loly,  J Belaiche]     Scandinavian journal of …  2008
# 12         [RK Russell,  HE Drummond]              … bowel diseases  2005
# 13                 [Y Mazor,  I Maza]          Journal of Crohn's …  2011
# 14            [F Rieder,  S Schleder]              … bowel diseases  2010
# 15  [A Bressenot,  L Peyrin-Biroulet]   Inflammatory Bowel Diseases  2015
#
#                           info
# 0    71회 인용 관련 학술자료 전체 10개의 버전
# 1   125회 인용 관련 학술자료 전체 11개의 버전
# 2    26회 인용 관련 학술자료 전체 16개의 버전
# 3     68회 인용 관련 학술자료 전체 8개의 버전
# 4   194회 인용 관련 학술자료 전체 10개의 버전
# 5   111회 인용 관련 학술자료 전체 10개의 버전
# 6   138회 인용 관련 학술자료 전체 10개의 버전
# 7   146회 인용 관련 학술자료 전체 12개의 버전
# 8     45회 인용 관련 학술자료 전체 8개의 버전
# 9   164회 인용 관련 학술자료 전체 18개의 버전
# 10    24회 인용 관련 학술자료 전체 8개의 버전
# 11   328회 인용 관련 학술자료 전체 6개의 버전
# 12   141회 인용 관련 학술자료 전체 9개의 버전
# 13    32회 인용 관련 학술자료 전체 8개의 버전
# 14   87회 인용 관련 학술자료 전체 14개의 버전
# 15    34회 인용 관련 학술자료 전체 6개의 버전
